# %%
#%matplotlib widget
import numpy as np

# %%
def extract_data(path: str, savetype: str = 'npy', extractpath:str = './run_extracted/'):
    """
     # rc, vg, rhog , M, T , re , cs  kappa
     #  0   1     2   3  4   5     6   7
        0,  2,    6,  8,10,  1,    9,  13
     this is for [:,:]

    savetype : npy or txt
    """
    # TODO add a save folder argument
    #    t  dt
    # 0  0  10 <-- this dt is to go from 0 to 1 etc 
    # 1 10  9  
    #    .  .
    #    .  .
    # n tn  0  <--- this dt should be 0 as we are done 
    cols = (0,2,6,8,10,1,9,13)
    if path[-1] != '/': path = path + '/'
    savepath    = extractpath + path[2:]
    try:     os.stat (extractpath)
    except:  os.mkdir(extractpath)
    try:     os.stat (savepath)
    except:  os.mkdir(savepath)

    output_files = os.listdir(path)


    data   = np.loadtxt(path + output_files[0],usecols = cols) # NOTE first file handled here for pre assigning memory
    nsteps = len(output_files)
    ncells = len(data[:,0])
    time   = np.zeros((2,nsteps))
    with open(path + output_files[0]) as filedata: # NOTE t for would always start at 0 so this is just in case
        tstring     = filedata.readline()
        ieq         = tstring.find('=') + 1 ; isec = tstring.find('s')
        time[0,0]   = np.float64(tstring[ieq:isec]) 
    data_extracted  = np.zeros((ncells, 7, nsteps))#NOTE also change number here to len of usecols
    data_extracted[:,:, 0] = data
    for idx, output in enumerate(output_files[1:],1):
        with open(path + output) as filedata:
            tstring     = filedata.readline()
            ieq         = tstring.find('=') + 1 ; isec = tstring.find('s')
            time[0,idx] = np.float64(tstring[ieq:isec]) 
            data_extracted[:,:,idx] = np.loadtxt(filedata,usecols = cols)
    time[1,:-1] = time[0, 1:] - time[0, :-1]
    if  savetype == 'npy':
        np.save(savepath + 'data',data_extracted)
        np.save(savepath + 'time', time)
    elif savetype == 'txt':
        np.savetxt(savepath + 'data',data_extracted)
        np.savetxt(savepath + 'time', time)
    print('Done Extrating')
#extract_data('./run067')

# %%
extract_data('./run067')
#extract_data(path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-ec3ee528ae67> in <module>()
# ----> 1 extract_data('./run067')
#       2 #extract_data(path)
#
# <ipython-input-2-fa896b74acd3> in extract_data(path, savetype, extractpath)
#      32         time[0,0]   = np.float64(tstring[ieq:isec])
#      33     data_extracted  = np.zeros((ncells, 7, nsteps))#NOTE also change number here to len of usecols
# ---> 34     data_extracted[:,:, 0] = data
#      35     for idx, output in enumerate(output_files[1:],1):
#      36         with open(path + output) as filedata:
#
# ValueError: could not broadcast input array from shape (4096,8) into shape (4096,7)

# %%
A = np.load('./run_extracted/run067/data.npy')

# %%
A[:,6,0]
# Out:
# array([24398.50783996, 24398.50783996, 24398.50783996, ...,
#        24398.5077393 , 24398.50773921, 24398.50773912])
